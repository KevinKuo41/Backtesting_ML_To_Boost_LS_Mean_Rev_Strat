# %% [markdown]
# ## Model Comparison (L/S)

# %% [markdown]
# ### (1) Quintile Strategy

# %%
cum_Q_strategy_return = pd.concat([cum_OLS_Q_strategy_return.rename('OLS Quintile L/S Mean Reversion Strategy'),
                                     cum_RF_Q_strategy_return.rename('RF Quintile L/S Mean Reversion Strategy'),
                                     cum_XGB_Q_strategy_return.rename('XGB Quintile L/S Mean Reversion Strategy'),
                                     cum_NN2_Q_strategy_return.rename('NN2 Quintile L/S Mean Reversion Strategy'),
                                     cum_NN3_Q_strategy_return.rename('NN3 Quintile L/S Mean Reversion Strategy'),
                                     cum_NN4_Q_strategy_return.rename('NN4 Quintile L/S Mean Reversion Strategy'),
                                     cum_NN5_Q_strategy_return.rename('NN5 Quintile L/S Mean Reversion Strategy'),
                                     cum_NN6_Q_strategy_return.rename('NN6 Quintile L/S Mean Reversion Strategy'),
                                     cum_LSTM_Q_strategy_return.rename('LSTM Quintile L/S Mean Reversion Strategy')], axis=1)

ax_Q = cum_Q_strategy_return.plot(grid=True, figsize=(12, 6), fontsize=10, linewidth=2)
plt.legend(fontsize=12, loc='upper left')
plt.ylabel('NAV Changes (Initial NAV: 100)', fontsize=12)
plt.xlabel('Year', fontsize=12)
plt.xticks(x, x)
plt.tight_layout()
plt.title('Cumulative Return for Quintile L/S Mean Reversion Strategy with Equally-weighted Portfolio on US Stocks', fontsize=12)
plt.show()

# %%
# Performance Stats
Q_stats = pd.concat([stats_OLS_Q, stats_RF_Q, stats_XGB_Q, stats_NN2_Q, stats_NN3_Q, stats_NN4_Q, stats_NN5_Q, stats_NN6_Q, stats_LSTM_Q], axis=0)
display(Q_stats)
# Out:
#                                      Total Return  Avg Return   Rf Rate  \
# OLS Quintile (Initial NAV: 100)          1.569753    0.039687  0.018682
# RF Quintile (Initial NAV: 100)          11.252236    0.111270  0.018682
# XGBoost Quintile (Initial NAV: 100)      9.003108    0.101821  0.018682
# NN2 Quintile (Initial NAV: 100)         10.388719    0.107856  0.018682
# NN3 Quintile (Initial NAV: 100)         10.972314    0.110189  0.018682
# NN4 Quintile (Initial NAV: 100)         11.073966    0.110584  0.018682
# NN5 Quintile (Initial NAV: 100)         11.249372    0.111259  0.018682
# NN6 Quintile (Initial NAV: 100)         10.397811    0.107893  0.018682
# LSTM Quintile (Initial NAV: 100)         2.087045    0.049677  0.018682
#
#                                      Volatility  Sharpe Ratio  Skewness  \
# OLS Quintile (Initial NAV: 100)        0.064070      0.327844 -1.192248
# RF Quintile (Initial NAV: 100)         0.047048      1.967934  0.716797
# ...

# %%
Q_stats2 = pd.concat([stats2_OLS_Q, stats2_RF_Q, stats2_XGB_Q, stats2_NN2_Q, stats2_NN3_Q, stats2_NN4_Q, stats2_NN5_Q, stats2_NN6_Q, stats2_LSTM_Q], axis=0)
display(Q_stats2)
# Out:
#                                  Total Return  Avg Monthly Return  \
# OLS Quintile (Long & Short)          1.569753            0.003249
# (Long Position)                    252.160063            0.019199
# (Short Position)                    -0.987987           -0.015080
# RF Quintile (Long & Short)          11.252236            0.008831
# (Long Position)                   1204.797880            0.025207
# (Short Position)                    -0.935349           -0.009564
# XGBoost Quintile (Long & Short)      9.003108            0.008113
# (Long Position)                   1003.235247            0.024549
# (Short Position)                    -0.950138           -0.010466
# NN2 Quintile (Long & Short)         10.388719            0.008572
# (Long Position)                   1118.202751            0.024939
# (Short Position)                    -0.941133           -0.009889
# NN3 Quintile (Long & Short)         10.972314            0.008749
# ...

# %% [markdown]
# ### (2) Decile Strategy

# %%
cum_D_strategy_return = pd.concat([cum_OLS_D_strategy_return.rename('OLS Decile L/S Mean Reversion Strategy'),
                                     cum_RF_D_strategy_return.rename('RF Decile L/S Mean Reversion Strategy'),
                                     cum_XGB_D_strategy_return.rename('XGB Decile L/S Mean Reversion Strategy'),
                                     cum_NN2_D_strategy_return.rename('NN2 Decile L/S Mean Reversion Strategy'),
                                     cum_NN3_D_strategy_return.rename('NN3 Decile L/S Mean Reversion Strategy'),
                                     cum_NN4_D_strategy_return.rename('NN4 Decile L/S Mean Reversion Strategy'),
                                     cum_NN5_D_strategy_return.rename('NN5 Decile L/S Mean Reversion Strategy'),
                                     cum_NN6_D_strategy_return.rename('NN6 Decile L/S Mean Reversion Strategy'),
                                     cum_LSTM_D_strategy_return.rename('LSTM Decile L/S Mean Reversion Strategy')], axis=1)

ax_D = cum_D_strategy_return.plot(grid=True, figsize=(12, 6), fontsize=10, linewidth=2)
plt.legend(fontsize=12, loc='upper left')
plt.ylabel('NAV Changes (Initial NAV: 100)', fontsize=12)
plt.xlabel('Year', fontsize=12)
plt.xticks(x, x)
plt.tight_layout()
plt.title('Cumulative Return for Decile L/S Mean Reversion Strategy with Equally-weighted Portfolio on US Stocks', fontsize=12)
plt.show()

# %%
# Performance Stats
D_stats = pd.concat([stats_OLS_D, stats_RF_D, stats_XGB_D, stats_NN2_D, stats_NN3_D, stats_NN4_D, stats_NN5_D, stats_NN6_D, stats_LSTM_D], axis=0)
display(D_stats)
# Out:
#                                    Total Return  Avg Return   Rf Rate  \
# OLS Decile (Initial NAV: 100)          2.454319    0.052448  0.018682
# RF Decile (Initial NAV: 100)          30.244258    0.155946  0.018682
# XGBoost Decile (Initial NAV: 100)     15.639149    0.125683  0.018682
# NN2 Decile (Initial NAV: 100)         25.364903    0.147711  0.018682
# NN3 Decile (Initial NAV: 100)         30.093040    0.155710  0.018682
# NN4 Decile (Initial NAV: 100)         29.592416    0.154921  0.018682
# NN5 Decile (Initial NAV: 100)         33.355523    0.160576  0.018682
# NN6 Decile (Initial NAV: 100)         29.363385    0.154555  0.018682
# LSTM Decile (Initial NAV: 100)         3.849807    0.070270  0.018682
#
#                                    Volatility  Sharpe Ratio  Skewness  \
# OLS Decile (Initial NAV: 100)        0.065299      0.517086 -0.399121
# RF Decile (Initial NAV: 100)         0.055447      2.475584  0.984646
# ...

# %%
D_stats2 = pd.concat([stats2_OLS_D, stats2_RF_D, stats2_XGB_D, stats2_NN2_D, stats2_NN3_D, stats2_NN4_D, stats2_NN5_D, stats2_NN6_D, stats2_LSTM_D], axis=0)
display(D_stats2)
# Out:
#                                Total Return  Avg Monthly Return   Avg Mkt Cap  \
# OLS Decile (Long & Short)          2.454319            0.004269  2.848441e+10
# (Long Position)                  616.954315            0.022330  3.197428e+09
# (Short Position)                  -0.991299           -0.016171  5.116239e+10
# RF Decile (Long & Short)          30.244258            0.012150  6.208299e+10
# (Long Position)                 8379.901362            0.032205  5.379736e+08
# (Short Position)                  -0.938749           -0.009751  1.160745e+11
# XGBoost Decile (Long & Short)     15.639149            0.009915  3.922592e+10
# (Long Position)                 4019.861626            0.029548  1.800703e+09
# (Short Position)                  -0.966641           -0.011860  7.292211e+10
# NN2 Decile (Long & Short)         25.364903            0.011547  4.900787e+10
# (Long Position)                 5984.259183            0.030986  1.586582e+09
# ...

# %% [markdown]
# ### (3) 20ths Divided Strategy

# %%
cum_T_strategy_return = pd.concat([cum_OLS_T_strategy_return.rename('OLS 20ths L/S Mean Reversion Strategy'),
                                     cum_RF_T_strategy_return.rename('RF 20ths L/S Mean Reversion Strategy'),
                                     cum_XGB_T_strategy_return.rename('XGB 20ths L/S Mean Reversion Strategy'),
                                     cum_NN2_T_strategy_return.rename('NN2 20ths L/S Mean Reversion Strategy'),
                                     cum_NN3_T_strategy_return.rename('NN3 20ths L/S Mean Reversion Strategy'),
                                     cum_NN4_T_strategy_return.rename('NN4 20ths L/S Mean Reversion Strategy'),
                                     cum_NN5_T_strategy_return.rename('NN5 20ths L/S Mean Reversion Strategy'),
                                     cum_NN6_T_strategy_return.rename('NN6 20ths L/S Mean Reversion Strategy'),
                                     cum_LSTM_T_strategy_return.rename('LSTM 20ths L/S Mean Reversion Strategy')], axis=1)

ax_T = cum_T_strategy_return.plot(grid=True, figsize=(12, 6), fontsize=10, linewidth=2)
plt.legend(fontsize=12, loc='upper left')
plt.ylabel('NAV Changes (Initial NAV: 100)', fontsize=12)
plt.xlabel('Year', fontsize=12)
plt.xticks(x, x)
plt.tight_layout()
plt.title('Cumulative Return for 20ths Divided L/S Mean Reversion Strategy with Equally-weighted Portfolio on US Stocks', fontsize=12)
plt.show()

# %%
# Performance Stats
T_stats = pd.concat([stats_OLS_T, stats_RF_T, stats_XGB_T, stats_NN2_T, stats_NN3_T, stats_NN4_T, stats_NN5_T, stats_NN6_T, stats_LSTM_T], axis=0)
display(T_stats)
# Out:
#                                   Total Return  Avg Return   Rf Rate  \
# OLS 20ths (Initial NAV: 100)          2.114006    0.047956  0.018682
# RF 20ths (Initial NAV: 100)          73.017932    0.198696  0.018682
# XGBoost 20ths (Initial NAV: 100)     21.756693    0.140621  0.018682
# NN2 20ths (Initial NAV: 100)         47.490823    0.177539  0.018682
# NN3 20ths (Initial NAV: 100)         72.639271    0.198437  0.018682
# NN4 20ths (Initial NAV: 100)         90.562877    0.209480  0.018682
# NN5 20ths (Initial NAV: 100)        103.512981    0.216236  0.018682
# NN6 20ths (Initial NAV: 100)         81.700114    0.204307  0.018682
# LSTM 20ths (Initial NAV: 100)         6.195353    0.088585  0.018682
#
#                                   Volatility  Sharpe Ratio  Skewness  \
# OLS 20ths (Initial NAV: 100)        0.059712      0.490246 -0.096700
# RF 20ths (Initial NAV: 100)         0.066709      2.698478  0.842081
# ...

# %%
T_stats2 = pd.concat([stats2_OLS_T, stats2_RF_T, stats2_XGB_T, stats2_NN2_T, stats2_NN3_T, stats2_NN4_T, stats2_NN5_T, stats2_NN6_T, stats2_LSTM_T], axis=0)
display(T_stats2)
# Out:
#                               Total Return  Avg Monthly Return   Avg Mkt Cap  \
# OLS 20ths (Long & Short)          2.114006            0.003911  3.022323e+10
# (Long Position)                1082.445255            0.024304  2.831480e+09
# (Short Position)                 -0.996221           -0.018987  5.322709e+10
# RF 20ths (Long & Short)          73.017932            0.015217  1.040810e+11
# (Long Position)               50266.556444            0.038713  5.348494e+08
# (Short Position)                 -0.944764           -0.010110  1.898131e+11
# XGBoost 20ths (Long & Short)     21.756693            0.011025  5.384777e+10
# (Long Position)                8354.958055            0.032194  2.245823e+09
# (Short Position)                 -0.972060           -0.012475  9.886923e+10
# NN2 20ths (Long & Short)         47.490823            0.013712  7.626550e+10
# (Long Position)               27148.992820            0.036471  1.853399e+09
# ...

# %% [markdown]
# ### (4) Percentile Strategy

# %%
cum_P_strategy_return = pd.concat([cum_OLS_P_strategy_return.rename('OLS Percentile L/S Mean Reversion Strategy'),
                                     cum_RF_P_strategy_return.rename('RF Percentile L/S Mean Reversion Strategy'),
                                     cum_XGB_P_strategy_return.rename('XGB Percentile L/S Mean Reversion Strategy'),
                                     cum_NN2_P_strategy_return.rename('NN2 Percentile L/S Mean Reversion Strategy'),
                                     cum_NN3_P_strategy_return.rename('NN3 Percentile L/S Mean Reversion Strategy'),
                                     cum_NN4_P_strategy_return.rename('NN4 Percentile L/S Mean Reversion Strategy'),
                                     cum_NN5_P_strategy_return.rename('NN5 Percentile L/S Mean Reversion Strategy'),
                                     cum_NN6_P_strategy_return.rename('NN6 Percentile L/S Mean Reversion Strategy'),
                                     cum_LSTM_P_strategy_return.rename('LSTM Percentile L/S Mean Reversion Strategy')], axis=1)

ax_P = cum_P_strategy_return.plot(grid=True, figsize=(12, 6), fontsize=10, linewidth=2)
plt.legend(fontsize=12, loc='upper left')
plt.ylabel('NAV Changes (Initial NAV: 100)', fontsize=12)
plt.xlabel('Year', fontsize=12)
plt.xticks(x, x)
plt.tight_layout()
plt.title('Cumulative Return for Percentile L/S Mean Reversion Strategy with Equally-weighted Portfolio on US Stocks', fontsize=12)
plt.show()

# %%
# Performance Stats
P_stats = pd.concat([stats_OLS_P, stats_RF_P, stats_XGB_P, stats_NN2_P, stats_NN3_P, stats_NN4_P, stats_NN5_P, stats_NN6_P, stats_LSTM_P], axis=0)
display(P_stats.round(3))
# Out:
#                                        Total Return  Avg Return  Rf Rate  \
# OLS Percentile (Initial NAV: 100)             0.486       0.016    0.019
# RF Percentile (Initial NAV: 100)            128.742       0.227    0.019
# XGBoost Percentile (Initial NAV: 100)         1.412       0.038    0.019
# NN2 Percentile (Initial NAV: 100)            29.596       0.155    0.019
# NN3 Percentile (Initial NAV: 100)            46.942       0.177    0.019
# NN4 Percentile (Initial NAV: 100)           120.683       0.224    0.019
# NN5 Percentile (Initial NAV: 100)           226.602       0.257    0.019
# NN6 Percentile (Initial NAV: 100)            76.991       0.201    0.019
# LSTM Percentile (Initial NAV: 100)           23.673       0.148    0.019
#
#                                        Volatility  Sharpe Ratio  Skewness  \
# OLS Percentile (Initial NAV: 100)           0.079        -0.028     0.334
# RF Percentile (Initial NAV: 100)            0.092         2.278     0.062
# ...

# %%
P_stats2 = pd.concat([stats2_OLS_P, stats2_RF_P, stats2_XGB_P, stats2_NN2_P, stats2_NN3_P, stats2_NN4_P, stats2_NN5_P, stats2_NN6_P, stats2_LSTM_P], axis=0)
display(P_stats2.round(3))
# Out:
#                                    Total Return  Avg Monthly Return  \
# OLS Percentile (Long & Short)             0.486               0.001
# (Long Position)                         648.845               0.023
# (Short Position)                         -0.999              -0.023
# RF Percentile (Long & Short)            128.742               0.017
# (Long Position)                      339376.455               0.046
# (Short Position)                         -0.979              -0.013
# XGBoost Percentile (Long & Short)         1.412               0.003
# (Long Position)                         509.001               0.022
# (Short Position)                         -0.996              -0.019
# NN2 Percentile (Long & Short)            29.596               0.012
# (Long Position)                       22261.592               0.036
# (Short Position)                         -0.983              -0.014
# NN3 Percentile (Long & Short)            46.942               0.014
# ...

# %% [markdown]
# ## Model Comparison (Long Only)

# %% [markdown]
# ### (1) Quintile Strategy

# %%
cum_OLS_Q_strategy_return_L = get_price_df(df_OLS_Quintile_Signal.replace(-1, 0), df_returns, nav=100, model_type=None)
cum_RF_Q_strategy_return_L = get_price_df(df_RF_Quintile_Signal.replace(-1, 0), df_returns, nav=100, model_type='ML')
cum_XGB_Q_strategy_return_L = get_price_df(df_XGB_Quintile_Signal.replace(-1, 0), df_returns, nav=100, model_type='ML')
cum_NN2_Q_strategy_return_L = get_price_df(df_NN2_Quintile_Signal.replace(-1, 0), df_returns, nav=100, model_type='ML')
cum_NN3_Q_strategy_return_L = get_price_df(df_NN3_Quintile_Signal.replace(-1, 0), df_returns, nav=100, model_type='ML')
cum_NN4_Q_strategy_return_L = get_price_df(df_NN4_Quintile_Signal.replace(-1, 0), df_returns, nav=100, model_type='ML')
cum_NN5_Q_strategy_return_L = get_price_df(df_NN5_Quintile_Signal.replace(-1, 0), df_returns, nav=100, model_type='ML')
cum_NN6_Q_strategy_return_L = get_price_df(df_NN6_Quintile_Signal.replace(-1, 0), df_returns, nav=100, model_type='ML')
cum_LSTM_Q_strategy_return_L = get_price_df(df_LSTM_Quintile_Signal.replace(-1, 0), df_returns, nav=100, model_type='LSTM')

# %%
cum_Q_strategy_return_L = pd.concat([cum_OLS_Q_strategy_return_L.rename('OLS Quintile L Mean Reversion Strategy'),
                                     cum_RF_Q_strategy_return_L.rename('RF Quintile L Mean Reversion Strategy'),
                                     cum_XGB_Q_strategy_return_L.rename('XGB Quintile L Mean Reversion Strategy'),
                                     cum_NN2_Q_strategy_return_L.rename('NN2 Quintile L Mean Reversion Strategy'),
                                     cum_NN3_Q_strategy_return_L.rename('NN3 Quintile L Mean Reversion Strategy'),
                                     cum_NN4_Q_strategy_return_L.rename('NN4 Quintile L Mean Reversion Strategy'),
                                     cum_NN5_Q_strategy_return_L.rename('NN5 Quintile L Mean Reversion Strategy'),
                                     cum_NN6_Q_strategy_return_L.rename('NN6 Quintile L Mean Reversion Strategy'),
                                     cum_LSTM_Q_strategy_return_L.rename('LSTM Quintile L Mean Reversion Strategy')], axis=1)

ax_Q_L = cum_Q_strategy_return_L.plot(grid=True, figsize=(12, 6), fontsize=10, linewidth=2)
plt.legend(fontsize=12, loc='upper left')
plt.ylabel('NAV Changes (Initial NAV: 100)', fontsize=12)
plt.xlabel('Year', fontsize=12)
plt.xticks(x, x)
plt.tight_layout()
plt.title('Cumulative Return for Quintile Long-only Mean Reversion Strategy with Equally-weighted Portfolio on US Stocks', fontsize=12)
plt.show()

# %% [markdown]
# ### (2) Decile Strategy

# %%
cum_OLS_D_strategy_return_L = get_price_df(df_OLS_Decile_Signal.replace(-1, 0), df_returns, nav=100, model_type=None)
cum_RF_D_strategy_return_L = get_price_df(df_RF_Decile_Signal.replace(-1, 0), df_returns, nav=100, model_type='ML')
cum_XGB_D_strategy_return_L = get_price_df(df_XGB_Decile_Signal.replace(-1, 0), df_returns, nav=100, model_type='ML')
cum_NN2_D_strategy_return_L = get_price_df(df_NN2_Decile_Signal.replace(-1, 0), df_returns, nav=100, model_type='ML')
cum_NN3_D_strategy_return_L = get_price_df(df_NN3_Decile_Signal.replace(-1, 0), df_returns, nav=100, model_type='ML')
cum_NN4_D_strategy_return_L = get_price_df(df_NN4_Decile_Signal.replace(-1, 0), df_returns, nav=100, model_type='ML')
cum_NN5_D_strategy_return_L = get_price_df(df_NN5_Decile_Signal.replace(-1, 0), df_returns, nav=100, model_type='ML')
cum_NN6_D_strategy_return_L = get_price_df(df_NN6_Decile_Signal.replace(-1, 0), df_returns, nav=100, model_type='ML')
cum_LSTM_D_strategy_return_L = get_price_df(df_LSTM_Decile_Signal.replace(-1, 0), df_returns, nav=100, model_type='LSTM')

# %%
cum_D_strategy_return_L = pd.concat([cum_OLS_D_strategy_return_L.rename('OLS Decile L Mean Reversion Strategy'),
                                     cum_RF_D_strategy_return_L.rename('RF Decile L Mean Reversion Strategy'),
                                     cum_XGB_D_strategy_return_L.rename('XGB Decile L Mean Reversion Strategy'),
                                     cum_NN2_D_strategy_return_L.rename('NN2 Decile L Mean Reversion Strategy'),
                                     cum_NN3_D_strategy_return_L.rename('NN3 Decile L Mean Reversion Strategy'),
                                     cum_NN4_D_strategy_return_L.rename('NN4 Decile L Mean Reversion Strategy'),
                                     cum_NN5_D_strategy_return_L.rename('NN5 Decile L Mean Reversion Strategy'),
                                     cum_NN6_D_strategy_return_L.rename('NN6 Decile L Mean Reversion Strategy'),
                                     cum_LSTM_D_strategy_return_L.rename('LSTM Decile L Mean Reversion Strategy')], axis=1)

ax_D_L = cum_D_strategy_return_L.plot(grid=True, figsize=(12, 6), fontsize=10, linewidth=2)
plt.legend(fontsize=12, loc='upper left')
plt.ylabel('NAV Changes (Initial NAV: 100)', fontsize=12)
plt.xlabel('Year', fontsize=12)
plt.xticks(x, x)
plt.tight_layout()
plt.title('Cumulative Return for Decile Long-only Mean Reversion Strategy with Equally-weighted Portfolio on US Stocks', fontsize=12)
plt.show()

# %% [markdown]
# ### (3) 20ths Divided Strategy

# %%
cum_OLS_T_strategy_return_L = get_price_df(df_OLS_20_Divided_Signal.replace(-1, 0), df_returns, nav=100, model_type=None)
cum_RF_T_strategy_return_L = get_price_df(df_RF_20_Divided_Signal.replace(-1, 0), df_returns, nav=100, model_type='ML')
cum_XGB_T_strategy_return_L = get_price_df(df_XGB_20_Divided_Signal.replace(-1, 0), df_returns, nav=100, model_type='ML')
cum_NN2_T_strategy_return_L = get_price_df(df_NN2_20_Divided_Signal.replace(-1, 0), df_returns, nav=100, model_type='ML')
cum_NN3_T_strategy_return_L = get_price_df(df_NN3_20_Divided_Signal.replace(-1, 0), df_returns, nav=100, model_type='ML')
cum_NN4_T_strategy_return_L = get_price_df(df_NN4_20_Divided_Signal.replace(-1, 0), df_returns, nav=100, model_type='ML')
cum_NN5_T_strategy_return_L = get_price_df(df_NN5_20_Divided_Signal.replace(-1, 0), df_returns, nav=100, model_type='ML')
cum_NN6_T_strategy_return_L = get_price_df(df_NN6_20_Divided_Signal.replace(-1, 0), df_returns, nav=100, model_type='ML')
cum_LSTM_T_strategy_return_L = get_price_df(df_LSTM_20_Divided_Signal.replace(-1, 0), df_returns, nav=100, model_type='LSTM')

# %%
cum_T_strategy_return_L = pd.concat([cum_OLS_T_strategy_return_L.rename('OLS 20ths L Mean Reversion Strategy'),
                                     cum_RF_T_strategy_return_L.rename('RF 20ths L Mean Reversion Strategy'),
                                     cum_XGB_T_strategy_return_L.rename('XGB 20ths L Mean Reversion Strategy'),
                                     cum_NN2_T_strategy_return_L.rename('NN2 20ths L Mean Reversion Strategy'),
                                     cum_NN3_T_strategy_return_L.rename('NN3 20ths L Mean Reversion Strategy'),
                                     cum_NN4_T_strategy_return_L.rename('NN4 20ths L Mean Reversion Strategy'),
                                     cum_NN5_T_strategy_return_L.rename('NN5 20ths L Mean Reversion Strategy'),
                                     cum_NN6_T_strategy_return_L.rename('NN6 20ths L Mean Reversion Strategy'),
                                     cum_LSTM_T_strategy_return_L.rename('LSTM 20ths L Mean Reversion Strategy')], axis=1)

ax_T_L = cum_T_strategy_return_L.plot(grid=True, figsize=(12, 6), fontsize=10, linewidth=2)
plt.legend(fontsize=12, loc='upper left')
plt.ylabel('NAV Changes (Initial NAV: 100)', fontsize=12)
plt.xlabel('Year', fontsize=12)
plt.xticks(x, x)
plt.tight_layout()
plt.title('Cumulative Return for 20ths Long-only Mean Reversion Strategy with Equally-weighted Portfolio on US Stocks', fontsize=12)
plt.show()

# %% [markdown]
# ### (4) Percentile Strategy

# %%
cum_OLS_P_strategy_return_L = get_price_df(df_OLS_Percentile_Signal.replace(-1, 0), df_returns, nav=100, model_type=None)
cum_RF_P_strategy_return_L = get_price_df(df_RF_Percentile_Signal.replace(-1, 0), df_returns, nav=100, model_type='ML')
cum_XGB_P_strategy_return_L = get_price_df(df_XGB_Percentile_Signal.replace(-1, 0), df_returns, nav=100, model_type='ML')
cum_NN2_P_strategy_return_L = get_price_df(df_NN2_Percentile_Signal.replace(-1, 0), df_returns, nav=100, model_type='ML')
cum_NN3_P_strategy_return_L = get_price_df(df_NN3_Percentile_Signal.replace(-1, 0), df_returns, nav=100, model_type='ML')
cum_NN4_P_strategy_return_L = get_price_df(df_NN4_Percentile_Signal.replace(-1, 0), df_returns, nav=100, model_type='ML')
cum_NN5_P_strategy_return_L = get_price_df(df_NN5_Percentile_Signal.replace(-1, 0), df_returns, nav=100, model_type='ML')
cum_NN6_P_strategy_return_L = get_price_df(df_NN6_Percentile_Signal.replace(-1, 0), df_returns, nav=100, model_type='ML')
cum_LSTM_P_strategy_return_L = get_price_df(df_LSTM_Percentile_Signal.replace(-1, 0), df_returns, nav=100, model_type='LSTM')

# %%
cum_P_strategy_return_L = pd.concat([cum_OLS_P_strategy_return_L.rename('OLS Percentile L Mean Reversion Strategy'),
                                     cum_RF_P_strategy_return_L.rename('RF Percentile L Mean Reversion Strategy'),
                                     cum_XGB_P_strategy_return_L.rename('XGB Percentile L Mean Reversion Strategy'),
                                     cum_NN2_P_strategy_return_L.rename('NN2 Percentile L Mean Reversion Strategy'),
                                     cum_NN3_P_strategy_return_L.rename('NN3 Percentile L Mean Reversion Strategy'),
                                     cum_NN4_P_strategy_return_L.rename('NN4 Percentile L Mean Reversion Strategy'),
                                     cum_NN5_P_strategy_return_L.rename('NN5 Percentile L Mean Reversion Strategy'),
                                     cum_NN6_P_strategy_return_L.rename('NN6 Percentile L Mean Reversion Strategy'),
                                     cum_LSTM_P_strategy_return_L.rename('LSTM Percentile L Mean Reversion Strategy')], axis=1)

ax_P_L = cum_P_strategy_return_L.plot(grid=True, figsize=(12, 6), fontsize=10, linewidth=2)
plt.legend(fontsize=12, loc='upper left')
plt.ylabel('NAV Changes (Initial NAV: 100)', fontsize=12)
plt.xlabel('Year', fontsize=12)
plt.xticks(x, x)
plt.tight_layout()
plt.title('Cumulative Return for Percentile Long-only Mean Reversion Strategy with Equally-weighted Portfolio on US Stocks', fontsize=12)
plt.show()

# %% [markdown]
# ## Model Comparison (Short Only)

# %% [markdown]
# ### (1) Quintile Strategy

# %%
cum_OLS_Q_strategy_return_S = get_price_df(df_OLS_Quintile_Signal.replace([1, -1], [0, 1]), df_returns, nav=100, model_type=None)
cum_RF_Q_strategy_return_S = get_price_df(df_RF_Quintile_Signal.replace([1, -1], [0, 1]), df_returns, nav=100, model_type='ML')
cum_XGB_Q_strategy_return_S = get_price_df(df_XGB_Quintile_Signal.replace([1, -1], [0, 1]), df_returns, nav=100, model_type='ML')
cum_NN2_Q_strategy_return_S = get_price_df(df_NN2_Quintile_Signal.replace([1, -1], [0, 1]), df_returns, nav=100, model_type='ML')
cum_NN3_Q_strategy_return_S = get_price_df(df_NN3_Quintile_Signal.replace([1, -1], [0, 1]), df_returns, nav=100, model_type='ML')
cum_NN4_Q_strategy_return_S = get_price_df(df_NN4_Quintile_Signal.replace([1, -1], [0, 1]), df_returns, nav=100, model_type='ML')
cum_NN5_Q_strategy_return_S = get_price_df(df_NN5_Quintile_Signal.replace([1, -1], [0, 1]), df_returns, nav=100, model_type='ML')
cum_NN6_Q_strategy_return_S = get_price_df(df_NN6_Quintile_Signal.replace([1, -1], [0, 1]), df_returns, nav=100, model_type='ML')
cum_LSTM_Q_strategy_return_S = get_price_df(df_LSTM_Quintile_Signal.replace([1, -1], [0, 1]), df_returns, nav=100, model_type='LSTM')

# %%
cum_Q_strategy_return_S = pd.concat([cum_OLS_Q_strategy_return_S.rename('OLS Quintile S Mean Reversion Strategy'),
                                     cum_RF_Q_strategy_return_S.rename('RF Quintile S Mean Reversion Strategy'),
                                     cum_XGB_Q_strategy_return_S.rename('XGB Quintile S Mean Reversion Strategy'),
                                     cum_NN2_Q_strategy_return_S.rename('NN2 Quintile S Mean Reversion Strategy'),
                                     cum_NN3_Q_strategy_return_S.rename('NN3 Quintile S Mean Reversion Strategy'),
                                     cum_NN4_Q_strategy_return_S.rename('NN4 Quintile S Mean Reversion Strategy'),
                                     cum_NN5_Q_strategy_return_S.rename('NN5 Quintile S Mean Reversion Strategy'),
                                     cum_NN6_Q_strategy_return_S.rename('NN6 Quintile S Mean Reversion Strategy'),
                                     cum_LSTM_Q_strategy_return_S.rename('LSTM Quintile S Mean Reversion Strategy')], axis=1)

ax_Q_S = cum_Q_strategy_return_S.plot(grid=True, figsize=(12, 6), fontsize=10, linewidth=2)
plt.legend(fontsize=12, loc='upper left')
plt.ylabel('NAV Changes (Initial NAV: 100)', fontsize=12)
plt.xlabel('Year', fontsize=12)
plt.xticks(x, x)
plt.tight_layout()
plt.title('Cumulative Return for Quintile Short-only Mean Reversion Strategy with Equally-weighted Portfolio on US Stocks', fontsize=12)
plt.show()

# %% [markdown]
# ### (2) Decile Strategy

# %%
cum_OLS_D_strategy_return_S = get_price_df(df_OLS_Decile_Signal.replace([1, -1], [0, 1]), df_returns, nav=100, model_type=None)
cum_RF_D_strategy_return_S = get_price_df(df_RF_Decile_Signal.replace([1, -1], [0, 1]), df_returns, nav=100, model_type='ML')
cum_XGB_D_strategy_return_S = get_price_df(df_XGB_Decile_Signal.replace([1, -1], [0, 1]), df_returns, nav=100, model_type='ML')
cum_NN2_D_strategy_return_S = get_price_df(df_NN2_Decile_Signal.replace([1, -1], [0, 1]), df_returns, nav=100, model_type='ML')
cum_NN3_D_strategy_return_S = get_price_df(df_NN3_Decile_Signal.replace([1, -1], [0, 1]), df_returns, nav=100, model_type='ML')
cum_NN4_D_strategy_return_S = get_price_df(df_NN4_Decile_Signal.replace([1, -1], [0, 1]), df_returns, nav=100, model_type='ML')
cum_NN5_D_strategy_return_S = get_price_df(df_NN5_Decile_Signal.replace([1, -1], [0, 1]), df_returns, nav=100, model_type='ML')
cum_NN6_D_strategy_return_S = get_price_df(df_NN6_Decile_Signal.replace([1, -1], [0, 1]), df_returns, nav=100, model_type='ML')
cum_LSTM_D_strategy_return_S = get_price_df(df_LSTM_Decile_Signal.replace([1, -1], [0, 1]), df_returns, nav=100, model_type='LSTM')

# %%
cum_D_strategy_return_S = pd.concat([cum_OLS_D_strategy_return_S.rename('OLS Decile S Mean Reversion Strategy'),
                                     cum_RF_D_strategy_return_S.rename('RF Decile S Mean Reversion Strategy'),
                                     cum_XGB_D_strategy_return_S.rename('XGB Decile S Mean Reversion Strategy'),
                                     cum_NN2_D_strategy_return_S.rename('NN2 Decile S Mean Reversion Strategy'),
                                     cum_NN3_D_strategy_return_S.rename('NN3 Decile S Mean Reversion Strategy'),
                                     cum_NN4_D_strategy_return_S.rename('NN4 Decile S Mean Reversion Strategy'),
                                     cum_NN5_D_strategy_return_S.rename('NN5 Decile S Mean Reversion Strategy'),
                                     cum_NN6_D_strategy_return_S.rename('NN6 Decile S Mean Reversion Strategy'),
                                     cum_LSTM_D_strategy_return_S.rename('LSTM Decile S Mean Reversion Strategy')], axis=1)

ax_D_S = cum_D_strategy_return_S.plot(grid=True, figsize=(12, 6), fontsize=10, linewidth=2)
plt.legend(fontsize=12, loc='upper left')
plt.ylabel('NAV Changes (Initial NAV: 100)', fontsize=12)
plt.xlabel('Year', fontsize=12)
plt.xticks(x, x)
plt.tight_layout()
plt.title('Cumulative Return for Decile Short-only Mean Reversion Strategy with Equally-weighted Portfolio on US Stocks', fontsize=12)
plt.show()

# %% [markdown]
# ### (3) 20ths Divided Strategy

# %%
cum_OLS_T_strategy_return_S = get_price_df(df_OLS_20_Divided_Signal.replace([1, -1], [0, 1]), df_returns, nav=100, model_type=None)
cum_RF_T_strategy_return_S = get_price_df(df_RF_20_Divided_Signal.replace([1, -1], [0, 1]), df_returns, nav=100, model_type='ML')
cum_XGB_T_strategy_return_S = get_price_df(df_XGB_20_Divided_Signal.replace([1, -1], [0, 1]), df_returns, nav=100, model_type='ML')
cum_NN2_T_strategy_return_S = get_price_df(df_NN2_20_Divided_Signal.replace([1, -1], [0, 1]), df_returns, nav=100, model_type='ML')
cum_NN3_T_strategy_return_S = get_price_df(df_NN3_20_Divided_Signal.replace([1, -1], [0, 1]), df_returns, nav=100, model_type='ML')
cum_NN4_T_strategy_return_S = get_price_df(df_NN4_20_Divided_Signal.replace([1, -1], [0, 1]), df_returns, nav=100, model_type='ML')
cum_NN5_T_strategy_return_S = get_price_df(df_NN5_20_Divided_Signal.replace([1, -1], [0, 1]), df_returns, nav=100, model_type='ML')
cum_NN6_T_strategy_return_S = get_price_df(df_NN6_20_Divided_Signal.replace([1, -1], [0, 1]), df_returns, nav=100, model_type='ML')
cum_LSTM_T_strategy_return_S = get_price_df(df_LSTM_20_Divided_Signal.replace([1, -1], [0, 1]), df_returns, nav=100, model_type='LSTM')

# %%
cum_T_strategy_return_S = pd.concat([cum_OLS_T_strategy_return_S.rename('OLS 20ths S Mean Reversion Strategy'),
                                     cum_RF_T_strategy_return_S.rename('RF 20ths S Mean Reversion Strategy'),
                                     cum_XGB_T_strategy_return_S.rename('XGB 20ths S Mean Reversion Strategy'),
                                     cum_NN2_T_strategy_return_S.rename('NN2 20ths S Mean Reversion Strategy'),
                                     cum_NN3_T_strategy_return_S.rename('NN3 20ths S Mean Reversion Strategy'),
                                     cum_NN4_T_strategy_return_S.rename('NN4 20ths S Mean Reversion Strategy'),
                                     cum_NN5_T_strategy_return_S.rename('NN5 20ths S Mean Reversion Strategy'),
                                     cum_NN6_T_strategy_return_S.rename('NN6 20ths S Mean Reversion Strategy'),
                                     cum_LSTM_T_strategy_return_S.rename('LSTM 20ths S Mean Reversion Strategy')], axis=1)

ax_T_S = cum_T_strategy_return_S.plot(grid=True, figsize=(12, 6), fontsize=10, linewidth=2)
plt.legend(fontsize=12, loc='upper left')
plt.ylabel('NAV Changes (Initial NAV: 100)', fontsize=12)
plt.xlabel('Year', fontsize=12)
plt.xticks(x, x)
plt.tight_layout()
plt.title('Cumulative Return for 20ths Short-only Mean Reversion Strategy with Equally-weighted Portfolio on US Stocks', fontsize=12)
plt.show()

# %% [markdown]
# ### (4) Percentile Strategy

# %%
cum_OLS_P_strategy_return_S = get_price_df(df_OLS_Percentile_Signal.replace([1, -1], [0, 1]), df_returns, nav=100, model_type=None)
cum_RF_P_strategy_return_S = get_price_df(df_RF_Percentile_Signal.replace([1, -1], [0, 1]), df_returns, nav=100, model_type='ML')
cum_XGB_P_strategy_return_S = get_price_df(df_XGB_Percentile_Signal.replace([1, -1], [0, 1]), df_returns, nav=100, model_type='ML')
cum_NN2_P_strategy_return_S = get_price_df(df_NN2_Percentile_Signal.replace([1, -1], [0, 1]), df_returns, nav=100, model_type='ML')
cum_NN3_P_strategy_return_S = get_price_df(df_NN3_Percentile_Signal.replace([1, -1], [0, 1]), df_returns, nav=100, model_type='ML')
cum_NN4_P_strategy_return_S = get_price_df(df_NN4_Percentile_Signal.replace([1, -1], [0, 1]), df_returns, nav=100, model_type='ML')
cum_NN5_P_strategy_return_S = get_price_df(df_NN5_Percentile_Signal.replace([1, -1], [0, 1]), df_returns, nav=100, model_type='ML')
cum_NN6_P_strategy_return_S = get_price_df(df_NN6_Percentile_Signal.replace([1, -1], [0, 1]), df_returns, nav=100, model_type='ML')
cum_LSTM_P_strategy_return_S = get_price_df(df_LSTM_Percentile_Signal.replace([1, -1], [0, 1]), df_returns, nav=100, model_type='LSTM')

# %%
cum_P_strategy_return_S = pd.concat([cum_OLS_P_strategy_return_S.rename('OLS Percentile S Mean Reversion Strategy'),
                                     cum_RF_P_strategy_return_S.rename('RF Percentile S Mean Reversion Strategy'),
                                     cum_XGB_P_strategy_return_S.rename('XGB Percentile S Mean Reversion Strategy'),
                                     cum_NN2_P_strategy_return_S.rename('NN2 Percentile S Mean Reversion Strategy'),
                                     cum_NN3_P_strategy_return_S.rename('NN3 Percentile S Mean Reversion Strategy'),
                                     cum_NN4_P_strategy_return_S.rename('NN4 Percentile S Mean Reversion Strategy'),
                                     cum_NN5_P_strategy_return_S.rename('NN5 Percentile S Mean Reversion Strategy'),
                                     cum_NN6_P_strategy_return_S.rename('NN6 Percentile S Mean Reversion Strategy'),
                                     cum_LSTM_P_strategy_return_S.rename('LSTM Percentile S Mean Reversion Strategy')], axis=1)

ax_P_S = cum_P_strategy_return_S.plot(grid=True, figsize=(12, 6), fontsize=10, linewidth=2)
plt.legend(fontsize=12, loc='upper left')
plt.ylabel('NAV Changes (Initial NAV: 100)', fontsize=12)
plt.xlabel('Year', fontsize=12)
plt.xticks(x, x)
plt.tight_layout()
plt.title('Cumulative Return for Percentile Short-only Mean Reversion Strategy with Equally-weighted Portfolio on US Stocks', fontsize=12)
plt.show()
